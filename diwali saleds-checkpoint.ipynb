# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"C:\Users\gupta\OneDrive\Desktop\Diwali Sales Data.csv")
print(df)
# Out:
#        User_ID    Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0      1002903    Sanskriti  P00125942      F     26-35   28               0
# 1      1000732       Kartik  P00110942      F     26-35   35               1
# 2      1001990        Bindu  P00118542      F     26-35   35               1
# 3      1001425       Sudevi  P00237842      M      0-17   16               0
# 4      1000588         Joni  P00057942      M     26-35   28               1
# ...        ...          ...        ...    ...       ...  ...             ...
# 11246  1000695      Manning  P00296942      M     18-25   19               1
# 11247  1004089  Reichenbach  P00171342      M     26-35   33               0
# 11248  1001209        Oshin  P00201342      F     36-45   40               0
# 11249  1004023       Noonan  P00059442      M     36-45   37               0
# 11250  1002744      Brumley  P00281742      F     18-25   19               0
#
# ...

# %%
df.shape
# Out:
# (11251, 15)

# %%
df.head(20)
# Out:
#     User_ID  Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0   1002903  Sanskriti  P00125942      F     26-35   28               0
# 1   1000732     Kartik  P00110942      F     26-35   35               1
# 2   1001990      Bindu  P00118542      F     26-35   35               1
# 3   1001425     Sudevi  P00237842      M      0-17   16               0
# 4   1000588       Joni  P00057942      M     26-35   28               1
# 5   1000588       Joni  P00057942      M     26-35   28               1
# 6   1001132       Balk  P00018042      F     18-25   25               1
# 7   1002092   Shivangi  P00273442      F       55+   61               0
# 8   1003224     Kushal  P00205642      M     26-35   35               0
# 9   1003650      Ginny  P00031142      F     26-35   26               1
# 10  1003829   Harshita  P00200842      M     26-35   34               0
# 11  1000214   Kargatis  P00119142      F     18-25   20               0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11251 entries, 0 to 11250
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           11251 non-null  int64
#  1   Cust_name         11251 non-null  object
#  2   Product_ID        11251 non-null  object
#  3   Gender            11251 non-null  object
#  4   Age Group         11251 non-null  object
#  5   Age               11251 non-null  int64
#  6   Marital_Status    11251 non-null  int64
#  7   State             11251 non-null  object
#  8   Zone              11251 non-null  object
#  9   Occupation        11251 non-null  object
#  10  Product_Category  11251 non-null  object
#  11  Orders            11251 non-null  int64
#  12  Amount            11239 non-null  float64
#  13  Status            0 non-null      float64
#  14  unnamed1          0 non-null      float64
# dtypes: float64(3), int64(4), object(8)
# memory usage: 1.3+ MB

# %%
df.drop(["Status","unnamed1"],axis = 1,inplace=True,errors="ignore")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11251 entries, 0 to 11250
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           11251 non-null  int64
#  1   Cust_name         11251 non-null  object
#  2   Product_ID        11251 non-null  object
#  3   Gender            11251 non-null  object
#  4   Age Group         11251 non-null  object
#  5   Age               11251 non-null  int64
#  6   Marital_Status    11251 non-null  int64
#  7   State             11251 non-null  object
#  8   Zone              11251 non-null  object
#  9   Occupation        11251 non-null  object
#  10  Product_Category  11251 non-null  object
#  11  Orders            11251 non-null  int64
#  12  Amount            11239 non-null  float64
# dtypes: float64(1), int64(4), object(8)
# memory usage: 1.1+ MB

# %%
pd.isnull(df)
# Out:
#        User_ID  Cust_name  Product_ID  Gender  Age Group    Age  \
# 0        False      False       False   False      False  False
# 1        False      False       False   False      False  False
# 2        False      False       False   False      False  False
# 3        False      False       False   False      False  False
# 4        False      False       False   False      False  False
# ...        ...        ...         ...     ...        ...    ...
# 11246    False      False       False   False      False  False
# 11247    False      False       False   False      False  False
# 11248    False      False       False   False      False  False
# 11249    False      False       False   False      False  False
# 11250    False      False       False   False      False  False
#
#        Marital_Status  State   Zone  Occupation  Product_Category  Orders  \
# 0               False  False  False       False             False   False
# ...

# %%
pd.isnull(df).sum()
# Out:
# User_ID              0
# Cust_name            0
# Product_ID           0
# Gender               0
# Age Group            0
# Age                  0
# Marital_Status       0
# State                0
# Zone                 0
# Occupation           0
# Product_Category     0
# Orders               0
# Amount              12
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
pd.isnull(df).sum()
# Out:
# User_ID             0
# Cust_name           0
# Product_ID          0
# Gender              0
# Age Group           0
# Age                 0
# Marital_Status      0
# State               0
# Zone                0
# Occupation          0
# Product_Category    0
# Orders              0
# Amount              0
# dtype: int64

# %%
df["Amount"] = df["Amount"].astype("int")

# %%
df.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age Group', 'Age',
#        'Marital_Status', 'State', 'Zone', 'Occupation', 'Product_Category',
#        'Orders', 'Amount'],
#       dtype='object')

# %%
df.rename(columns = {"Marital_Status":"Shaadi"})
# Out:
#        User_ID    Cust_name Product_ID Gender Age Group  Age  Shaadi  \
# 0      1002903    Sanskriti  P00125942      F     26-35   28       0
# 1      1000732       Kartik  P00110942      F     26-35   35       1
# 2      1001990        Bindu  P00118542      F     26-35   35       1
# 3      1001425       Sudevi  P00237842      M      0-17   16       0
# 4      1000588         Joni  P00057942      M     26-35   28       1
# ...        ...          ...        ...    ...       ...  ...     ...
# 11246  1000695      Manning  P00296942      M     18-25   19       1
# 11247  1004089  Reichenbach  P00171342      M     26-35   33       0
# 11248  1001209        Oshin  P00201342      F     36-45   40       0
# 11249  1004023       Noonan  P00059442      M     36-45   37       0
# 11250  1002744      Brumley  P00281742      F     18-25   19       0
#
#                 State      Zone       Occupation Product_Category  Orders  \
# ...

# %%
df.describe()
# Out:
#             User_ID           Age  Marital_Status        Orders        Amount
# count  1.123900e+04  11239.000000    11239.000000  11239.000000  11239.000000
# mean   1.003004e+06     35.410357        0.420055      2.489634   9453.610553
# std    1.716039e+03     12.753866        0.493589      1.114967   5222.355168
# min    1.000001e+06     12.000000        0.000000      1.000000    188.000000
# 25%    1.001492e+06     27.000000        0.000000      2.000000   5443.000000
# 50%    1.003064e+06     33.000000        0.000000      2.000000   8109.000000
# 75%    1.004426e+06     43.000000        1.000000      3.000000  12675.000000
# max    1.006040e+06     92.000000        1.000000      4.000000  23952.000000

# %%
#####FOR GENDER

# %%
df.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age Group', 'Age',
#        'Marital_Status', 'State', 'Zone', 'Occupation', 'Product_Category',
#        'Orders', 'Amount'],
#       dtype='object')

# %%
ax = sns.countplot(x = "Gender",data = df)

for bars in ax.containers:
    ax.bar_label(bars)

# %%
x = df["Amount"].sum()
print(x)
# Out:
# 106249129

# %%
df.groupby(["Gender"])["Amount"].sum()
# Out:
# Gender
# F    74335853
# M    31913276
# Name: Amount, dtype: int32

# %% [markdown]
# AGE
# AGE
# AGE

# %%
sns.countplot(x = 'Age Group',data = df)
# Out:
# <Axes: xlabel='Age Group', ylabel='count'>

# %%
ax = sns.countplot(x = 'Age Group',data = df,hue = 'Gender')
for bars in ax.containers:
    ax.bar_label(bars)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[50], line 1
# ----> 1 ax = sns.countplot(x = 'Age Group',data = df,hue = 'Gender').sort()
#       2 for bars in ax.containers:
#       3     ax.bar_label(bars)
#
# AttributeError: 'Axes' object has no attribute 'sort'

# %%
df.groupby(["Age Group"])["Amount"].sum()
# Out:
# Age Group
# 0-17      2699653
# 18-25    17240732
# 26-35    42613442
# 36-45    22144994
# 46-50     9207844
# 51-55     8261477
# 55+       4080987
# Name: Amount, dtype: int32

# %%
result = pd.crosstab(df["Age Group"],df["Gender"])
print(result)
# Out:
# Gender        F     M
# Age Group
# 0-17        162   134
# 18-25      1305   574
# 26-35      3269  1272
# 36-45      1578   705
# 46-50       693   290
# 51-55       553   277
# 55+         272   155

# %%
df.groupby(["Age Group","Gender"]).size().unstack(fill_value=0)
# Out:
# Gender        F     M
# Age Group
# 0-17        162   134
# 18-25      1305   574
# 26-35      3269  1272
# 36-45      1578   705
# 46-50       693   290
# 51-55       553   277
# 55+         272   155

# %%
ax = sns.barplot(x = "Orders",y = "State",data = df)
for bars in ax.containers:
    ax.bar_label(bars)

# %%
ax = sns.barplot(x = "Amount",y = "State",data = df)
for bars in ax.containers:
    ax.bar_label(bars)

# %%
df.groupby(["State","Gender"])["Amount"].sum().unstack(fill_value=0)
# Out:
# Gender                   F        M
# State
# Andhra?radesh      5511219  2525927
# Bihar              2819281  1203476
# Delhi              8264498  3339320
# Gujarat            2832262  1113820
# Haryana            3198296  1021879
# Himachal Pradesh   3163299  1800069
# Jharkhand          1954275  1072181
# Karnataka          9933966  3589574
# Kerala             2644087  1250404
# Madhya Pradesh     5301046  2800096
# Maharashtra       10560976  3866567
# Punjab              950267   575533
# Rajasthan          1243444   665965
# Telangana           703814   447676
# Uttar Pradesh     13662105  5712863
# Uttarakhand        1593018   927926

# %%
df.groupby(["State"])["Amount"].sum()
# Out:
# State
# Andhra?radesh        8037146
# Bihar                4022757
# Delhi               11603818
# Gujarat              3946082
# Haryana              4220175
# Himachal Pradesh     4963368
# Jharkhand            3026456
# Karnataka           13523540
# Kerala               3894491
# Madhya Pradesh       8101142
# Maharashtra         14427543
# Punjab               1525800
# Rajasthan            1909409
# Telangana            1151490
# Uttar Pradesh       19374968
# Uttarakhand          2520944
# Name: Amount, dtype: int32

# %%
df.groupby(["State","Gender"]).size().unstack(fill_value=0)
# Out:
# Gender               F    M
# State
# Andhra?radesh      554  257
# Bihar              303  131
# Delhi              748  356
# Gujarat            306  121
# Haryana            325  127
# Himachal Pradesh   423  185
# Jharkhand          264  116
# Karnataka          914  390
# Kerala             319  134
# Madhya Pradesh     618  303
# Maharashtra       1110  415
# Punjab             134   66
# Rajasthan          149   82
# Telangana           76   49
# Uttar Pradesh     1371  573
# Uttarakhand        218  102

# %%
df.groupby(["State"])["Orders"].sum()
# Out:
# State
# Andhra?radesh       2051
# Bihar               1062
# Delhi               2740
# Gujarat             1066
# Haryana             1109
# Himachal Pradesh    1568
# Jharkhand            953
# Karnataka           3240
# Kerala              1137
# Madhya Pradesh      2252
# Maharashtra         3810
# Punjab               495
# Rajasthan            555
# Telangana            312
# Uttar Pradesh       4807
# Uttarakhand          824
# Name: Orders, dtype: int64

# %% [markdown]
# MARITAL STATUS
# MARITAL STATUS
# MARITAL STATUS

# %%
ax = sns.countplot(data = df, x = "Marital_Status")
for bars in ax.containers:
    ax.bar_label(bars)

# %%
ax = sns.barplot(data = df, x = "Marital_Status",y = "Amount",hue = "Gender")
for bars in ax.containers:
    ax.bar_label(bars)

# %%
 df.groupby(["State","Marital_Status","Gender"])["Amount"].sum().unstack(fill_value=0)
# Out:
# Gender                                 F        M
# State            Marital_Status
# Andhra?radesh    0               3270401  1462588
#                  1               2240818  1063339
# Bihar            0               1499035   785010
#                  1               1320246   418466
# Delhi            0               4878274  1830195
#                  1               3386224  1509125
# Gujarat          0               1836541   609109
#                  1                995721   504711
# Haryana          0               1848410   686922
#                  1               1349886   334957
# Himachal Pradesh 0               1816090  1066290
#                  1               1347209   733779
# Jharkhand        0               1076233   647227
#                  1                878042   424954
# Karnataka        0               5896439  1909507
#                  1               4037527  1680067
# Kerala           0               1587032   671014
# ...

# %%
df.groupby(["Marital_Status"])["Amount"].sum()
# Out:
# Marital_Status
# 0    62125384
# 1    44123745
# Name: Amount, dtype: int32

# %%
df.head()
# Out:
#    User_ID  Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0  1002903  Sanskriti  P00125942      F     26-35   28               0
# 1  1000732     Kartik  P00110942      F     26-35   35               1
# 2  1001990      Bindu  P00118542      F     26-35   35               1
# 3  1001425     Sudevi  P00237842      M      0-17   16               0
# 4  1000588       Joni  P00057942      M     26-35   28               1
#
#            State      Zone       Occupation Product_Category  Orders  Amount
# 0    Maharashtra   Western       Healthcare             Auto       1   23952
# 1  Andhra?radesh  Southern             Govt             Auto       3   23934
# 2  Uttar Pradesh   Central       Automobile             Auto       3   23924
# 3      Karnataka  Southern     Construction             Auto       2   23912
# 4        Gujarat   Western  Food Processing             Auto       2   23877

# %%
ax = sns.countplot(y = 'Occupation',data = df)
for bars in ax.containers:
    ax.bar_label(bars)

# %%
z = df.groupby(["Occupation"])["Amount"].sum()
print(z)
print(z.min())
print(z.max())
# Out:
# Occupation
# Agriculture         2593087
# Automobile          5368596
# Aviation           12602298
# Banking            10770610
# Chemical            5297436
# Construction        3597511
# Food Processing     4070670
# Govt                8517212
# Healthcare         13034586
# Hospitality         6376405
# IT Sector          14755079
# Lawyer              4981665
# Media               6295832
# Retail              4783170
# Textile             3204972
# Name: Amount, dtype: int32
# 2593087
# 14755079

# %%
ax = sns.barplot(x = "Amount",y = 'Occupation',hue = 'Occupation',data = df,palette="Set2")
plt.show()

# %% [markdown]
# product category

# %%
ax = sns.countplot(data = df,y = "Product_Category")

# %%
df.groupby(["Product_Category"])["Amount"].sum()
# Out:
# Product_Category
# Auto                      1958609
# Beauty                    1959484
# Books                     1061478
# Clothing & Apparel       16495019
# Decor                      730360
# Electronics & Gadgets    15643846
# Food                     33933883
# Footwear & Shoes         15575209
# Furniture                 5440051
# Games & Toys              4331694
# Hand & Power Tools         405618
# Household items           1569337
# Office                      81936
# Pet Care                   482277
# Sports Products           3635933
# Stationery                1676051
# Tupperware                1155642
# Veterinary                 112702
# Name: Amount, dtype: int32

# %%
 res = df.groupby(["Product_Category","State","Age Group","Marital_Status","Gender"])["Amount"].sum().unstack(fill_value=0)
res.head(30)
# Out:
# Gender                                                           F      M
# Product_Category State            Age Group Marital_Status
# Auto             Andhra?radesh    0-17      0                 9732  23239
#                                   18-25     0               128199      0
#                                             1               122562      0
#                                   26-35     0               263412      0
#                                             1               169299  37878
#                                   36-45     0                79117  19022
#                                             1               127603      0
#                                   46-50     0                37607  18608
#                                   51-55     0                41626      0
#                                             1                41870      0
#                                   55+       0                14063      0
# ...

# %%
des = df.groupby(["Product_Category","State","Marital_Status","Gender"])["Amount"].sum().unstack(fill_value=0)
des.head(30)
# Out:
# Gender                                                 F      M
# Product_Category State            Marital_Status
# Auto             Andhra?radesh    0               573756  60869
#                                   1               461334  37878
#                  Bihar            0                    0  18609
#                  Delhi            0                    0  23770
#                                   1                    0  46384
#                  Gujarat          1                    0  23877
#                  Himachal Pradesh 1                    0  66439
#                  Jharkhand        0                    0  37738
#                                   1                    0  23285
#                  Karnataka        0                    0  61680
#                  Kerala           0                    0  41935
#                  Madhya Pradesh   0                    0  33015
#                                   1                    0  18685
# ...
